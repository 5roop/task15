# %%
from typing import Union, List
from pathlib import Path
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

mpdf = pd.read_pickle("mpdf_corrected")
partiesdf = pd.read_pickle("partiesdf_corrected")
termdata = pd.read_csv("../terms.csv").set_index("Term")

def transform_abbreviation(s: str) -> str:
    return f"party.{s.replace(' ', '_').upper().replace('!', '')}"

# Fix ambiguous codemps:
mpdf.loc[mpdf.fullname.isin(["Lovrić Merzel, Marina"]), "codemp"] = "M393"
mpdf.loc[mpdf.fullname.isin(["Vrbat Grgić, Tanja"]), "codemp"] = "M581" 

# Fix swapped first- and last-names:
def make_firstname(s: str) -> str:
    return s.split(", ")[-1]
def make_lastname(s: str) -> str:
    return s.split(", ")[0]
from tqdm import tqdm
tqdm.pandas()
mpdf["firstname"] = mpdf.fullname.progress_apply(make_firstname)
mpdf["lastname"] = mpdf.fullname.progress_apply(make_lastname)
# Out:
# 100%|██████████| 1141/1141 [00:00<00:00, 413058.94it/s]
# 100%|██████████| 1141/1141 [00:00<00:00, 718789.56it/s]

# %% [markdown]
# # Preparing persons:

# %%
from xml.etree.ElementTree import Element, SubElement, tostring, XML, parse
from xml.dom import minidom
def pretty_print(s) -> None:
    print(minidom.parseString(tostring(s).decode("utf")).toprettyxml("\t"))
def pretty_string(s) -> None:
    return minidom.parseString(tostring(s).decode("utf")).toprettyxml("\t")

# %% [markdown]
# # Terms (line 438):
#
# path: `/teiCorpus/teiHeader/profileDesc/particDesc/listOrg/org[2]/listEvent`

# %%
listEvent = Element("listEvent")
head = SubElement(listEvent, "head")
head.set("xml:lang", "hr")
head.text = "Mandatno obdoblje"
head = SubElement(listEvent, "head")
head.set("xml:lang", "en")
head.text = "Legislative period"

for i, row in termdata.iterrows():
    event = SubElement(listEvent, "event")
    event.set("xml:id", f"HS.{i}")
    event.set("from", row["From"])
    to = row["To"]
    if not pd.isna(to):
        event.set("to", row["To"])
    
    label = SubElement(event, "label")
    label.set("xml:lang", "hr")
    label.text = f"{i}. mandat"
    label = SubElement(event, "label")
    label.set("xml:lang", "en")
    label.text = f"Term {i}"
listEvent_str = pretty_string(listEvent)
listEvent_str = "\n".join(listEvent_str.split("\n")[1:])
print(listEvent_str)
# Out:
# <listEvent>
# 	<head xml:lang="hr">Mandatno obdoblje</head>
# 	<head xml:lang="en">Legislative period</head>
# 	<event xml:id="HS.5" from="2003-12-22" to="2007-10-12">
# 		<label xml:lang="hr">5. mandat</label>
# 		<label xml:lang="en">Term 5</label>
# 	</event>
# 	<event xml:id="HS.6" from="2008-01-11" to="2011-10-28">
# 		<label xml:lang="hr">6. mandat</label>
# 		<label xml:lang="en">Term 6</label>
# 	</event>
# 	<event xml:id="HS.7" from="2011-12-22" to="2015-09-25">
# 		<label xml:lang="hr">7. mandat</label>
# 		<label xml:lang="en">Term 7</label>
# 	</event>
# 	<event xml:id="HS.8" from="2015-12-03" to="2016-07-15">
# 		<label xml:lang="hr">8. mandat</label>
# 		<label xml:lang="en">Term 8</label>
# 	</event>
# 	<event xml:id="HS.9" from="2016-10-14" to="2020-05-18">
# 		<label xml:lang="hr">9. mandat</label>
# 		<label xml:lang="en">Term 9</label>
# 	</event>
# 	<event xml:id="HS.10" from="2020-07-22">
# 		<label xml:lang="hr">10. mandat</label>
# 		<label xml:lang="en">Term 10</label>
# 	</event>
# </listEvent>

# %% [markdown]
# # Parties: line 447
#
# path:
# `/teiCorpus/teiHeader/profileDesc/particDesc/listOrg/org[3:]`

# %%
partiesdf["id"] = partiesdf.party.apply(transform_abbreviation)

partydata = partiesdf["party full_name id".split()].drop_duplicates()

orgs = []
for i, row in partydata.iterrows():
    org = Element("org")
    org.set("xml:id", row["id"])
    org.set("role", "parliamentaryGroup")
    orgName = SubElement(org, "orgName")
    orgName.set("full", "yes")
    orgName.set("xml:lang", "hr")
    orgName.text = row["full_name"]
    
    orgName = SubElement(org, "orgName")
    orgName.set("full", "abb")
    orgName.text = row["party"]
    orgs.append(org)
    
# Add nezavisni:
org = Element("org")
org.set("xml:id", "party.NEZAVISNI")
org.set("role", "parliamentaryGroup")
orgName = SubElement(org, "orgName")
orgName.set("full", "yes")
orgName.set("xml:lang", "hr")
orgName.text = "nezavisni"
orgName = SubElement(org, "orgName")
orgName.set("full", "abb")
orgName.text = "nezavisni"
orgs.append(org)

# Add Hrvatski suverenisti:
org = Element("org")
org.set("xml:id", "party.HS")
org.set("role", "parliamentaryGroup")
orgName = SubElement(org, "orgName")
orgName.set("full", "yes")
orgName.set("xml:lang", "hr")
orgName.text = "Hrvatski Suverenisti"
orgName = SubElement(org, "orgName")
orgName.set("full", "abb")
orgName.text = "HS"
orgs.append(org)

# Add Hrvatska konzervativna stranka
org = Element("org")
org.set("xml:id", "party.HKS")
org.set("role", "parliamentaryGroup")
orgName = SubElement(org, "orgName")
orgName.set("full", "yes")
orgName.set("xml:lang", "hr")
orgName.text = "Hrvatska konzervativna stranka"
orgName = SubElement(org, "orgName")
orgName.set("full", "abb")
orgName.text = "HKS"
orgs.append(org)


orgs = [pretty_string(i) for i in orgs]

orgstring = "\n".join(
    ["\n".join(org.split("\n")[1:])for org in orgs]
)
# print(orgstring)

# %% [markdown]
# # People: line 525
#
# path: `/teiCorpus/teiHeader/profileDesc/particDesc/listPerson`

# %%
for name in mpdf.fullname.unique():
    if mpdf.loc[mpdf.fullname==name, "codemp"].unique().shape[0] != 1:
        print(name, "\n", mpdf.loc[mpdf.fullname==name, "codemp"])

# %%
listPerson = []
codemps = mpdf.codemp.drop_duplicates()
n = 0
for i, c in enumerate(codemps):    
    subset = mpdf.query(f"codemp=='{c}'").reset_index(drop=True)
    surname = subset.lastname[0]
    forename = subset.firstname[0]
    sex = "M" if subset.gender[0] == 0 else "F"
    birth = str(subset.date_of_birth[0])
    birth = f"{birth[0:4]}-{birth[4:6]}-{birth[-2:]}"
    reference_name = f"{surname.replace(' ', '')}{forename.replace(' ', '')}"
    
    person = Element("person")
    person.set("xml:id", reference_name)
    person.set("n", str(c))
    n += 1
    persName = SubElement(person, "persName")
    
    buf = SubElement(persName, "surname")
    buf.text = surname
    
    buf = SubElement(persName, "forename")
    buf.text = forename
    
    buf = SubElement(person, "sex")
    buf.set("value", sex)
    
    buf = SubElement(person, "birth")
    buf.set("when", birth)
    

    for i, row in subset.drop_duplicates().iterrows():  
        term = row["term2"]
        fromto = termdata.loc[term, :]
        aff = SubElement(person, "affiliation")
        aff.set("role", "member")
        aff.set("ref", f"#{transform_abbreviation(row['party'])}")
        aff.set("from", fromto.From)
        if not pd.isna(fromto.To):
            aff.set("to", fromto.To)
        
        rolename = SubElement(aff, "roleName")
        rolename.set("xml:lang", "en")
        rolename.text = "Member"

        aff = SubElement(person, "affiliation")
        aff.set("role", "member")
        aff.set("ref", "#HS")
        aff.set("ana", f"#HS.{row['term2']}")
        aff.set("from", fromto.From)
        if not pd.isna(fromto.To):
            aff.set("to", fromto.To)
        rolename = SubElement(aff, "roleName")
        rolename.set("xml:lang", "en")
        rolename.text = "MP"
    listPerson.append(person)

# # Add Unknown to listPersons:
# reference_name = "Unknown"
# person = Element("person")
# person.set("xml:id", reference_name)
# person.set("n", str(n))
# n += 1
# persName = SubElement(person, "persName")
# buf = SubElement(persName, "surname")
# buf.text = "Unknown"
# buf = SubElement(persName, "forename")
# buf.text = "Unknown"
# listPerson.append(person)

# Add Marina to listPersons
reference_name = "MatulovićDropulićMarina"
person = Element("person")
person.set("xml:id", reference_name)
person.set("n", str(n))
n += 1
persName = SubElement(person, "persName")
buf = SubElement(persName, "surname")
buf.text = "Matulović Dropulić"
buf = SubElement(persName, "forename")
buf.text = "Marina"
buf = SubElement(person, "sex")
buf.set("value", "F")
listPerson.append(person)

# %%
listPerson = ["\n".join(pretty_string(p).split("\n")[1:]) for p in listPerson]
listPerson = "\n".join(listPerson)

# %%
path_to_term_tmxs = Path("/home/rupnik/parlamint/S/")
assert path_to_term_tmxs.exists()


xiincludes = ""
for file in sorted(list(path_to_term_tmxs.glob("ParlaMint-HR_T*.xml"))):
    xiincludes += f"""    <xi:include xmlns:xi="http://www.w3.org/2001/XInclude" href="{file.name}"/>\n"""

# %% [markdown]
# # Relations
#
# path: `/teiCorpus/teiHeader/profileDesc/particDesc/listOrg/listRelation`

# %%
# gb = partiesdf.groupby(["term2", "coalition"]).agg(
#     {
#         "id": lambda l: " ".join(set(["#"+i for i in l]))
#     }
# )

gb = partiesdf.groupby(["term2", "coalition"]).agg(
    {
        "id": lambda l: " ".join(set(["#"+i for i in l if i in partydata.id.values
                                      ]))
    }
)
terms = partiesdf.term2.unique()
listRelation = ""
for term in terms:
    fromto = termdata.loc[term, :]
    ind = (term, 1)
    coalition = gb.loc[ind].id
    ind = (term, 0)
    opposition = gb.loc[ind].id
    listRelation += f"""
    <relation name="coalition"
            mutual="{coalition}"
            from="{fromto.From}"
            {'to="'+fromto.To+'"' if not pd.isna(fromto.To) else ""}
            ana="#HS.{term}"/>
    <relation name="opposition"
            active="{opposition}"
            passive="#government.HR"
            from="{fromto.From}"
            {'to="'+fromto.To+'"' if not pd.isna(fromto.To) else ""}
            ana="#HS.{term}"/>\n"""

# %% [markdown]
# # Counting extents and tagUsages

# %%
from typing import Union
from pathlib import Path
def get_extent(path: Union[str, Path]):
    if isinstance(path, Path):
        assert path.exists()
        path = str(path)
    namespace= {
        "n": "http://www.tei-c.org/ns/1.0",
        
    }
    termtei = parse(path)
    measures = termtei.getroot().findall(".//n:measure", namespaces=namespace)
    for i in measures:
        if i.get("unit") == "speeches":
            speeches = i.get("quantity")
        if i.get("unit") == "words":
            words = i.get("quantity")
    return {"words": int(words), "speeches": int(speeches)}

def get_tagusage(path: Union[str, Path]):
    if isinstance(path, Path):
        assert path.exists()
        path = str(path)
    namespace= {
        "n": "http://www.tei-c.org/ns/1.0",
        
    }
    termtei = parse(path)
    tagusages = termtei.getroot().findall(".//n:tagUsage", namespaces=namespace)
    for i in tagusages:
        if i.get("unit") == "speeches":
            speeches = i.get("quantity")
        if i.get("unit") == "words":
            words = i.get("quantity")
    return {i.get("gi"): i.get("occurs") for i in tagusages}

path_to_term_tmxs = Path("/home/rupnik/parlamint/S/")
assert path_to_term_tmxs.exists()


extents = []
tagusages = []
for file in sorted(list(path_to_term_tmxs.glob("ParlaMint-HR_T*.xml"))):
    extents.append(get_extent(file))
    tagusages.append(get_tagusage(file))

tagusage = ""
import pandas as pd
tus = pd.DataFrame(data=tagusages).astype(int)
for gi, occurs in tus.sum().items():
    tagusage += f"""<tagUsage gi="{gi}" occurs="{int(occurs)}"/>\n"""
extent_count = pd.DataFrame(data=extents).astype(int).sum()
words = extent_count["words"]
speeches = extent_count["speeches"]
extent = f"""<measure unit="speeches" quantity="{speeches}" xml:lang="hr">{f'{speeches:,d}'.replace(',','.')} govora</measure>
<measure unit="speeches" quantity="{speeches}" xml:lang="en">{speeches:,d} speeches</measure>
<measure unit="words" quantity="{words}" xml:lang="hr">{f'{words:,d}'.replace(',','.')} riječi</measure>
<measure unit="words" quantity="{words}" xml:lang="en">{words:,d} words</measure>
"""

# %% [markdown]
# # Putting it all together

# %%
with open("/home/rupnik/parlamint/T/ParlaMint-HR_template2.xml") as f:
    content = f.read()
from string import Template
template = Template(content)
filled_in = template.substitute(
                    listEvent=listEvent_str,
                    orgs=orgstring,
                    listPerson = listPerson,
                    xiincludes = xiincludes,
                    listRelation = listRelation,
                    extent = extent,
                    tagusage = tagusage
                    )

with open("/home/rupnik/parlamint/S/ParlaMint-HR.xml", "w") as f:
    f.write(
        filled_in
    )

# %%
# %%bash
# pwd
# Out:
# /home/rupnik/parlamint/task15

# %%
# %%bash
#
# cp /home/rupnik/parlamint/S/ParlaMint-HR*.xml /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/
# # cp /home/rupnik/parlamint/S/ParlaMint-HR.xml /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/
#
# cd /home/rupnik/parlamint/ParlaMint
# make add-common-content-HR
# cd Data/ParlaMint-HR/
# cp add-common-content/* .
# rm -r add-common-content
# Out:
# rm -rf Data/ParlaMint-HR/add-common-content
# mkdir -p Data/ParlaMint-HR/add-common-content
# java -jar /usr/share/java/saxon.jar outDir=Data/ParlaMint-HR/add-common-content \
#    -xsl:Scripts/parlamint-add-common-content.xsl \
#    Data/ParlaMint-HR/ParlaMint-HR.ana.xml || :
# java -jar /usr/share/java/saxon.jar outDir=Data/ParlaMint-HR/add-common-content \
#    anaDir=`pwd`/Data/ParlaMint-HR/add-common-content/ParlaMint-HR \
#    -xsl:Scripts/parlamint-add-common-content.xsl \
#    Data/ParlaMint-HR/ParlaMint-HR.xml || :
# for component in `echo Data/ParlaMint-HR/ParlaMint-HR.ana.xml| xargs -I % java -cp /usr/share/java/saxon.jar net.sf.saxon.Query -xi:off \!method=adaptive -qs:'//*[local-name()="teiHeader"]//*[local-name()="include"]/@href' -s:% |sed 's/^ *href="//;s/"//'`; do \
#   echo "copying header component: Data/ParlaMint-HR/${component}" ; \
#     cp Data/ParlaMint-HR/${component} Data/ParlaMint-HR/add-common-content/ParlaMint-HR; \
# done;
# echo "Result is in: Data/ParlaMint-HR/add-common-content/ParlaMint-HR"
# Result is in: Data/ParlaMint-HR/add-common-content/ParlaMint-HR
# Source file Data/ParlaMint-HR/ParlaMint-HR.ana.xml does not exist
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S04.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S05.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S06.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S07.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S08.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S09.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S18.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S19.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S20.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S21.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S22.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S23.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S24.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S25.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S26.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T05_S27.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S04.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S05.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S06.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S07.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S08.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S09.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S18.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S19.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S20.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S21.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S22.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S23.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T06_S24.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S04.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S05.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S06.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S07.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S08.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S09.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S18.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S19.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T07_S20.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T08_S01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T08_S02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T08_S03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T09_S01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T09_S02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T09_S03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T09_S04.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S04.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S05.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S06.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S07.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S08.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S09.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/add-common-content/ParlaMint-HR/ParlaMint-HR_T10_S11.ana.xml
# INFO: Starting to process ParlaMint-HR
# INFO: Processing ParlaMint-HR_T05_S01.xml
# INFO ParlaMint-HR_T05_S01: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S01: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S01: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S01: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S01: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S01: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S01: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S01: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S01: preserving seg tagUsage 665
# INFO ParlaMint-HR_T05_S01: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S01: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S01: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S02.xml
# INFO ParlaMint-HR_T05_S02: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S02: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S02: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S02: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S02: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S02: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S02: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S02: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S02: preserving seg tagUsage 6137
# INFO ParlaMint-HR_T05_S02: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S02: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S02: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S03.xml
# INFO ParlaMint-HR_T05_S03: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S03: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S03: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S03: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S03: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S03: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S03: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S03: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S03: preserving seg tagUsage 17846
# INFO ParlaMint-HR_T05_S03: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S03: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S03: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S04.xml
# INFO ParlaMint-HR_T05_S04: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S04: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S04: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S04: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S04: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S04: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S04: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S04: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S04: preserving seg tagUsage 36615
# INFO ParlaMint-HR_T05_S04: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S04: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S04: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S05.xml
# INFO ParlaMint-HR_T05_S05: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S05: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S05: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S05: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S05: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S05: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S05: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S05: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S05: preserving seg tagUsage 25551
# INFO ParlaMint-HR_T05_S05: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S05: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S05: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S06.xml
# INFO ParlaMint-HR_T05_S06: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S06: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S06: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S06: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S06: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S06: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S06: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S06: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S06: preserving seg tagUsage 19374
# INFO ParlaMint-HR_T05_S06: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S06: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S06: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S07.xml
# INFO ParlaMint-HR_T05_S07: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S07: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S07: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S07: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S07: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S07: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S07: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S07: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S07: preserving seg tagUsage 41620
# INFO ParlaMint-HR_T05_S07: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S07: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S07: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S08.xml
# INFO ParlaMint-HR_T05_S08: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S08: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S08: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S08: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S08: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S08: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S08: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S08: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S08: preserving seg tagUsage 31613
# INFO ParlaMint-HR_T05_S08: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S08: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S08: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S09.xml
# INFO ParlaMint-HR_T05_S09: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S09: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S09: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S09: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S09: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S09: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S09: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S09: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S09: preserving seg tagUsage 66
# INFO ParlaMint-HR_T05_S09: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S09: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S09: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S10.xml
# INFO ParlaMint-HR_T05_S10: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S10: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S10: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S10: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S10: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S10: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S10: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S10: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S10: preserving seg tagUsage 42540
# INFO ParlaMint-HR_T05_S10: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S10: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S10: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S11.xml
# INFO ParlaMint-HR_T05_S11: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S11: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S11: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S11: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S11: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S11: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S11: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S11: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S11: preserving seg tagUsage 63923
# INFO ParlaMint-HR_T05_S11: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S11: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S11: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S12.xml
# INFO ParlaMint-HR_T05_S12: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S12: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S12: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S12: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S12: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S12: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S12: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S12: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S12: preserving seg tagUsage 41650
# INFO ParlaMint-HR_T05_S12: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S12: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S12: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S13.xml
# INFO ParlaMint-HR_T05_S13: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S13: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S13: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S13: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S13: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S13: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S13: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S13: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S13: preserving seg tagUsage 40050
# INFO ParlaMint-HR_T05_S13: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S13: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S13: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S14.xml
# INFO ParlaMint-HR_T05_S14: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S14: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S14: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S14: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S14: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S14: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S14: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S14: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S14: preserving seg tagUsage 26767
# INFO ParlaMint-HR_T05_S14: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S14: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S14: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S15.xml
# INFO ParlaMint-HR_T05_S15: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S15: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S15: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S15: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S15: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S15: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S15: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S15: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S15: preserving seg tagUsage 31496
# INFO ParlaMint-HR_T05_S15: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S15: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S15: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S16.xml
# INFO ParlaMint-HR_T05_S16: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S16: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S16: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S16: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S16: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S16: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S16: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S16: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S16: preserving seg tagUsage 40801
# INFO ParlaMint-HR_T05_S16: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S16: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S16: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S17.xml
# INFO ParlaMint-HR_T05_S17: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S17: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S17: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S17: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S17: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S17: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S17: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S17: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S17: preserving seg tagUsage 67729
# INFO ParlaMint-HR_T05_S17: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S17: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S17: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S18.xml
# INFO ParlaMint-HR_T05_S18: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S18: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S18: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S18: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S18: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S18: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S18: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S18: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S18: preserving seg tagUsage 37962
# INFO ParlaMint-HR_T05_S18: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S18: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S18: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S19.xml
# INFO ParlaMint-HR_T05_S19: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S19: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S19: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S19: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S19: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S19: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S19: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S19: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S19: preserving seg tagUsage 84672
# INFO ParlaMint-HR_T05_S19: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S19: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S19: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S20.xml
# INFO ParlaMint-HR_T05_S20: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S20: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S20: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S20: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S20: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S20: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S20: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S20: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S20: preserving seg tagUsage 41643
# INFO ParlaMint-HR_T05_S20: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S20: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S20: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S21.xml
# INFO ParlaMint-HR_T05_S21: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S21: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S21: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S21: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S21: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S21: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S21: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S21: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S21: preserving seg tagUsage 49172
# INFO ParlaMint-HR_T05_S21: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S21: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S21: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S22.xml
# INFO ParlaMint-HR_T05_S22: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S22: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S22: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S22: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S22: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S22: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S22: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S22: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S22: preserving seg tagUsage 31868
# INFO ParlaMint-HR_T05_S22: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S22: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S22: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S23.xml
# INFO ParlaMint-HR_T05_S23: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S23: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S23: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S23: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S23: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S23: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S23: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S23: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S23: preserving seg tagUsage 60045
# INFO ParlaMint-HR_T05_S23: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S23: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S23: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S24.xml
# INFO ParlaMint-HR_T05_S24: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S24: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S24: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S24: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S24: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S24: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S24: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S24: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S24: preserving seg tagUsage 43258
# INFO ParlaMint-HR_T05_S24: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S24: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S24: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S25.xml
# INFO ParlaMint-HR_T05_S25: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S25: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S25: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S25: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S25: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S25: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S25: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S25: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S25: preserving seg tagUsage 55022
# INFO ParlaMint-HR_T05_S25: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S25: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S25: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S26.xml
# INFO ParlaMint-HR_T05_S26: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S26: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S26: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S26: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S26: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S26: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S26: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S26: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S26: preserving seg tagUsage 50630
# INFO ParlaMint-HR_T05_S26: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S26: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S26: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T05_S27.xml
# INFO ParlaMint-HR_T05_S27: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T05_S27: preserving body tagUsage 1
# INFO ParlaMint-HR_T05_S27: removing desc tagUsage 0
# INFO ParlaMint-HR_T05_S27: preserving div tagUsage 1
# INFO ParlaMint-HR_T05_S27: removing gap tagUsage 0
# INFO ParlaMint-HR_T05_S27: removing head tagUsage 0
# INFO ParlaMint-HR_T05_S27: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T05_S27: removing note tagUsage 0
# INFO ParlaMint-HR_T05_S27: preserving seg tagUsage 26254
# INFO ParlaMint-HR_T05_S27: preserving text tagUsage 1
# INFO ParlaMint-HR_T05_S27: preserving u tagUsage 1
# INFO ParlaMint-HR_T05_S27: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S01.xml
# INFO ParlaMint-HR_T06_S01: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S01: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S01: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S01: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S01: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S01: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S01: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S01: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S01: preserving seg tagUsage 711
# INFO ParlaMint-HR_T06_S01: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S01: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S01: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S02.xml
# INFO ParlaMint-HR_T06_S02: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S02: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S02: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S02: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S02: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S02: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S02: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S02: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S02: preserving seg tagUsage 4939
# INFO ParlaMint-HR_T06_S02: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S02: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S02: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S03.xml
# INFO ParlaMint-HR_T06_S03: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S03: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S03: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S03: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S03: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S03: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S03: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S03: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S03: preserving seg tagUsage 50831
# INFO ParlaMint-HR_T06_S03: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S03: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S03: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S04.xml
# INFO ParlaMint-HR_T06_S04: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S04: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S04: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S04: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S04: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S04: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S04: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S04: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S04: preserving seg tagUsage 55218
# INFO ParlaMint-HR_T06_S04: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S04: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S04: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S05.xml
# INFO ParlaMint-HR_T06_S05: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S05: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S05: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S05: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S05: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S05: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S05: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S05: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S05: preserving seg tagUsage 45370
# INFO ParlaMint-HR_T06_S05: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S05: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S05: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S06.xml
# INFO ParlaMint-HR_T06_S06: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S06: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S06: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S06: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S06: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S06: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S06: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S06: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S06: preserving seg tagUsage 60826
# INFO ParlaMint-HR_T06_S06: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S06: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S06: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S07.xml
# INFO ParlaMint-HR_T06_S07: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S07: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S07: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S07: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S07: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S07: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S07: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S07: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S07: preserving seg tagUsage 56930
# INFO ParlaMint-HR_T06_S07: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S07: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S07: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S08.xml
# INFO ParlaMint-HR_T06_S08: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S08: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S08: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S08: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S08: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S08: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S08: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S08: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S08: preserving seg tagUsage 37274
# INFO ParlaMint-HR_T06_S08: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S08: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S08: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S09.xml
# INFO ParlaMint-HR_T06_S09: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S09: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S09: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S09: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S09: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S09: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S09: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S09: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S09: preserving seg tagUsage 39975
# INFO ParlaMint-HR_T06_S09: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S09: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S09: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S10.xml
# INFO ParlaMint-HR_T06_S10: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S10: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S10: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S10: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S10: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S10: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S10: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S10: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S10: preserving seg tagUsage 752
# INFO ParlaMint-HR_T06_S10: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S10: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S10: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S11.xml
# INFO ParlaMint-HR_T06_S11: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S11: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S11: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S11: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S11: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S11: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S11: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S11: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S11: preserving seg tagUsage 61372
# INFO ParlaMint-HR_T06_S11: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S11: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S11: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S12.xml
# INFO ParlaMint-HR_T06_S12: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S12: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S12: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S12: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S12: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S12: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S12: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S12: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S12: preserving seg tagUsage 35
# INFO ParlaMint-HR_T06_S12: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S12: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S12: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S13.xml
# INFO ParlaMint-HR_T06_S13: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S13: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S13: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S13: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S13: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S13: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S13: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S13: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S13: preserving seg tagUsage 15273
# INFO ParlaMint-HR_T06_S13: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S13: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S13: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S14.xml
# INFO ParlaMint-HR_T06_S14: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S14: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S14: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S14: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S14: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S14: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S14: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S14: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S14: preserving seg tagUsage 42583
# INFO ParlaMint-HR_T06_S14: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S14: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S14: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S15.xml
# INFO ParlaMint-HR_T06_S15: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S15: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S15: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S15: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S15: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S15: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S15: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S15: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S15: preserving seg tagUsage 34896
# INFO ParlaMint-HR_T06_S15: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S15: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S15: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S16.xml
# INFO ParlaMint-HR_T06_S16: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S16: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S16: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S16: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S16: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S16: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S16: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S16: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S16: preserving seg tagUsage 44056
# INFO ParlaMint-HR_T06_S16: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S16: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S16: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S17.xml
# INFO ParlaMint-HR_T06_S17: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S17: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S17: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S17: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S17: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S17: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S17: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S17: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S17: preserving seg tagUsage 33347
# INFO ParlaMint-HR_T06_S17: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S17: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S17: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S18.xml
# INFO ParlaMint-HR_T06_S18: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S18: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S18: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S18: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S18: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S18: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S18: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S18: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S18: preserving seg tagUsage 59067
# INFO ParlaMint-HR_T06_S18: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S18: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S18: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S19.xml
# INFO ParlaMint-HR_T06_S19: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S19: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S19: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S19: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S19: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S19: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S19: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S19: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S19: preserving seg tagUsage 3684
# INFO ParlaMint-HR_T06_S19: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S19: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S19: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S20.xml
# INFO ParlaMint-HR_T06_S20: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S20: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S20: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S20: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S20: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S20: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S20: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S20: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S20: preserving seg tagUsage 86610
# INFO ParlaMint-HR_T06_S20: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S20: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S20: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S21.xml
# INFO ParlaMint-HR_T06_S21: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S21: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S21: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S21: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S21: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S21: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S21: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S21: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S21: preserving seg tagUsage 1437
# INFO ParlaMint-HR_T06_S21: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S21: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S21: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S22.xml
# INFO ParlaMint-HR_T06_S22: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S22: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S22: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S22: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S22: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S22: removing head tagUsage 0
# INFO ParlaMint-HR_T06_S22: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T06_S22: removing note tagUsage 0
# INFO ParlaMint-HR_T06_S22: preserving seg tagUsage 50109
# INFO ParlaMint-HR_T06_S22: preserving text tagUsage 1
# INFO ParlaMint-HR_T06_S22: preserving u tagUsage 1
# INFO ParlaMint-HR_T06_S22: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T06_S23.xml
# INFO ParlaMint-HR_T06_S23: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T06_S23: preserving body tagUsage 1
# INFO ParlaMint-HR_T06_S23: removing desc tagUsage 0
# INFO ParlaMint-HR_T06_S23: preserving div tagUsage 1
# INFO ParlaMint-HR_T06_S23: removing gap tagUsage 0
# INFO ParlaMint-HR_T06_S23: removing head tagUsage 0
# ...
# INFO ParlaMint-HR_T07_S19: preserving body tagUsage 1
# INFO ParlaMint-HR_T07_S19: removing desc tagUsage 0
# INFO ParlaMint-HR_T07_S19: preserving div tagUsage 1
# INFO ParlaMint-HR_T07_S19: removing gap tagUsage 0
# INFO ParlaMint-HR_T07_S19: removing head tagUsage 0
# INFO ParlaMint-HR_T07_S19: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T07_S19: removing note tagUsage 0
# INFO ParlaMint-HR_T07_S19: preserving seg tagUsage 8409
# INFO ParlaMint-HR_T07_S19: preserving text tagUsage 1
# INFO ParlaMint-HR_T07_S19: preserving u tagUsage 1
# INFO ParlaMint-HR_T07_S19: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T07_S20.xml
# INFO ParlaMint-HR_T07_S20: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T07_S20: preserving body tagUsage 1
# INFO ParlaMint-HR_T07_S20: removing desc tagUsage 0
# INFO ParlaMint-HR_T07_S20: preserving div tagUsage 1
# INFO ParlaMint-HR_T07_S20: removing gap tagUsage 0
# INFO ParlaMint-HR_T07_S20: removing head tagUsage 0
# INFO ParlaMint-HR_T07_S20: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T07_S20: removing note tagUsage 0
# INFO ParlaMint-HR_T07_S20: preserving seg tagUsage 26782
# INFO ParlaMint-HR_T07_S20: preserving text tagUsage 1
# INFO ParlaMint-HR_T07_S20: preserving u tagUsage 1
# INFO ParlaMint-HR_T07_S20: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T08_S01.xml
# INFO ParlaMint-HR_T08_S01: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T08_S01: preserving body tagUsage 1
# INFO ParlaMint-HR_T08_S01: removing desc tagUsage 0
# INFO ParlaMint-HR_T08_S01: preserving div tagUsage 1
# INFO ParlaMint-HR_T08_S01: removing gap tagUsage 0
# INFO ParlaMint-HR_T08_S01: removing head tagUsage 0
# INFO ParlaMint-HR_T08_S01: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T08_S01: removing note tagUsage 0
# INFO ParlaMint-HR_T08_S01: preserving seg tagUsage 399
# INFO ParlaMint-HR_T08_S01: preserving text tagUsage 1
# INFO ParlaMint-HR_T08_S01: preserving u tagUsage 1
# INFO ParlaMint-HR_T08_S01: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T08_S02.xml
# INFO ParlaMint-HR_T08_S02: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T08_S02: preserving body tagUsage 1
# INFO ParlaMint-HR_T08_S02: removing desc tagUsage 0
# INFO ParlaMint-HR_T08_S02: preserving div tagUsage 1
# INFO ParlaMint-HR_T08_S02: removing gap tagUsage 0
# INFO ParlaMint-HR_T08_S02: removing head tagUsage 0
# INFO ParlaMint-HR_T08_S02: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T08_S02: removing note tagUsage 0
# INFO ParlaMint-HR_T08_S02: preserving seg tagUsage 72181
# INFO ParlaMint-HR_T08_S02: preserving text tagUsage 1
# INFO ParlaMint-HR_T08_S02: preserving u tagUsage 1
# INFO ParlaMint-HR_T08_S02: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T08_S03.xml
# INFO ParlaMint-HR_T08_S03: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T08_S03: preserving body tagUsage 1
# INFO ParlaMint-HR_T08_S03: removing desc tagUsage 0
# INFO ParlaMint-HR_T08_S03: preserving div tagUsage 1
# INFO ParlaMint-HR_T08_S03: removing gap tagUsage 0
# INFO ParlaMint-HR_T08_S03: removing head tagUsage 0
# INFO ParlaMint-HR_T08_S03: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T08_S03: removing note tagUsage 0
# INFO ParlaMint-HR_T08_S03: preserving seg tagUsage 53400
# INFO ParlaMint-HR_T08_S03: preserving text tagUsage 1
# INFO ParlaMint-HR_T08_S03: preserving u tagUsage 1
# INFO ParlaMint-HR_T08_S03: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T09_S01.xml
# INFO ParlaMint-HR_T09_S01: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T09_S01: preserving body tagUsage 1
# INFO ParlaMint-HR_T09_S01: removing desc tagUsage 0
# INFO ParlaMint-HR_T09_S01: preserving div tagUsage 1
# INFO ParlaMint-HR_T09_S01: removing gap tagUsage 0
# INFO ParlaMint-HR_T09_S01: removing head tagUsage 0
# INFO ParlaMint-HR_T09_S01: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T09_S01: removing note tagUsage 0
# INFO ParlaMint-HR_T09_S01: preserving seg tagUsage 172397
# INFO ParlaMint-HR_T09_S01: preserving text tagUsage 1
# INFO ParlaMint-HR_T09_S01: preserving u tagUsage 1
# INFO ParlaMint-HR_T09_S01: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T09_S02.xml
# INFO ParlaMint-HR_T09_S02: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T09_S02: preserving body tagUsage 1
# INFO ParlaMint-HR_T09_S02: removing desc tagUsage 0
# INFO ParlaMint-HR_T09_S02: preserving div tagUsage 1
# INFO ParlaMint-HR_T09_S02: removing gap tagUsage 0
# INFO ParlaMint-HR_T09_S02: removing head tagUsage 0
# INFO ParlaMint-HR_T09_S02: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T09_S02: removing note tagUsage 0
# INFO ParlaMint-HR_T09_S02: preserving seg tagUsage 60505
# INFO ParlaMint-HR_T09_S02: preserving text tagUsage 1
# INFO ParlaMint-HR_T09_S02: preserving u tagUsage 1
# INFO ParlaMint-HR_T09_S02: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T09_S03.xml
# INFO ParlaMint-HR_T09_S03: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T09_S03: preserving body tagUsage 1
# INFO ParlaMint-HR_T09_S03: removing desc tagUsage 0
# INFO ParlaMint-HR_T09_S03: preserving div tagUsage 1
# INFO ParlaMint-HR_T09_S03: removing gap tagUsage 0
# INFO ParlaMint-HR_T09_S03: removing head tagUsage 0
# INFO ParlaMint-HR_T09_S03: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T09_S03: removing note tagUsage 0
# INFO ParlaMint-HR_T09_S03: preserving seg tagUsage 127361
# INFO ParlaMint-HR_T09_S03: preserving text tagUsage 1
# INFO ParlaMint-HR_T09_S03: preserving u tagUsage 1
# INFO ParlaMint-HR_T09_S03: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T09_S04.xml
# INFO ParlaMint-HR_T09_S04: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T09_S04: preserving body tagUsage 1
# INFO ParlaMint-HR_T09_S04: removing desc tagUsage 0
# INFO ParlaMint-HR_T09_S04: preserving div tagUsage 1
# INFO ParlaMint-HR_T09_S04: removing gap tagUsage 0
# INFO ParlaMint-HR_T09_S04: removing head tagUsage 0
# INFO ParlaMint-HR_T09_S04: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T09_S04: removing note tagUsage 0
# INFO ParlaMint-HR_T09_S04: preserving seg tagUsage 47060
# INFO ParlaMint-HR_T09_S04: preserving text tagUsage 1
# INFO ParlaMint-HR_T09_S04: preserving u tagUsage 1
# INFO ParlaMint-HR_T09_S04: removing vocal tagUsage 0
# INFO: Processing ParlaMint-HR_T10_S01.xml
# WARN ParlaMint-HR_T10_S01: fixing subcorpus to covid for date 2020-07-22
# INFO ParlaMint-HR_T10_S01: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S01: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S01: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S01: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S01: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S01: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S01: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S01: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S01: preserving seg tagUsage 23871
# INFO ParlaMint-HR_T10_S01: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S01: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S01: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S01: fixing subcorpus to covid for date 2020-07-22
# INFO: Processing ParlaMint-HR_T10_S02.xml
# WARN ParlaMint-HR_T10_S02: fixing subcorpus to covid for date 2020-09-02
# INFO ParlaMint-HR_T10_S02: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S02: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S02: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S02: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S02: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S02: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S02: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S02: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S02: preserving seg tagUsage 10943
# INFO ParlaMint-HR_T10_S02: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S02: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S02: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S02: fixing subcorpus to covid for date 2020-09-02
# INFO: Processing ParlaMint-HR_T10_S03.xml
# WARN ParlaMint-HR_T10_S03: fixing subcorpus to covid for date 2020-09-16
# INFO ParlaMint-HR_T10_S03: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S03: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S03: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S03: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S03: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S03: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S03: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S03: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S03: preserving seg tagUsage 32095
# INFO ParlaMint-HR_T10_S03: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S03: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S03: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S03: fixing subcorpus to covid for date 2020-09-16
# INFO: Processing ParlaMint-HR_T10_S04.xml
# WARN ParlaMint-HR_T10_S04: fixing subcorpus to covid for date 2020-11-03
# INFO ParlaMint-HR_T10_S04: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S04: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S04: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S04: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S04: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S04: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S04: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S04: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S04: preserving seg tagUsage 115986
# INFO ParlaMint-HR_T10_S04: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S04: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S04: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S04: fixing subcorpus to covid for date 2020-11-03
# INFO: Processing ParlaMint-HR_T10_S05.xml
# WARN ParlaMint-HR_T10_S05: fixing subcorpus to covid for date 2020-12-16
# INFO ParlaMint-HR_T10_S05: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S05: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S05: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S05: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S05: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S05: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S05: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S05: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S05: preserving seg tagUsage 7356
# INFO ParlaMint-HR_T10_S05: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S05: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S05: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S05: fixing subcorpus to covid for date 2020-12-16
# INFO: Processing ParlaMint-HR_T10_S06.xml
# WARN ParlaMint-HR_T10_S06: fixing subcorpus to covid for date 2021-01-19
# INFO ParlaMint-HR_T10_S06: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S06: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S06: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S06: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S06: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S06: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S06: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S06: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S06: preserving seg tagUsage 108700
# INFO ParlaMint-HR_T10_S06: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S06: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S06: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S06: fixing subcorpus to covid for date 2021-01-19
# INFO: Processing ParlaMint-HR_T10_S07.xml
# WARN ParlaMint-HR_T10_S07: fixing subcorpus to covid for date 2021-04-07
# INFO ParlaMint-HR_T10_S07: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S07: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S07: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S07: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S07: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S07: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S07: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S07: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S07: preserving seg tagUsage 107986
# INFO ParlaMint-HR_T10_S07: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S07: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S07: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S07: fixing subcorpus to covid for date 2021-04-07
# INFO: Processing ParlaMint-HR_T10_S08.xml
# WARN ParlaMint-HR_T10_S08: fixing subcorpus to covid for date 2021-09-15
# INFO ParlaMint-HR_T10_S08: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S08: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S08: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S08: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S08: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S08: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S08: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S08: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S08: preserving seg tagUsage 99698
# INFO ParlaMint-HR_T10_S08: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S08: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S08: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S08: fixing subcorpus to covid for date 2021-09-15
# INFO: Processing ParlaMint-HR_T10_S09.xml
# WARN ParlaMint-HR_T10_S09: fixing subcorpus to covid for date 2021-11-24
# INFO ParlaMint-HR_T10_S09: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S09: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S09: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S09: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S09: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S09: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S09: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S09: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S09: preserving seg tagUsage 78971
# INFO ParlaMint-HR_T10_S09: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S09: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S09: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S09: fixing subcorpus to covid for date 2021-11-24
# INFO: Processing ParlaMint-HR_T10_S10.xml
# WARN ParlaMint-HR_T10_S10: fixing subcorpus to covid for date 2022-01-19
# INFO ParlaMint-HR_T10_S10: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S10: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S10: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S10: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S10: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S10: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S10: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S10: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S10: preserving seg tagUsage 142470
# INFO ParlaMint-HR_T10_S10: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S10: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S10: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S10: fixing subcorpus to covid for date 2022-01-19
# INFO: Processing ParlaMint-HR_T10_S11.xml
# WARN ParlaMint-HR_T10_S11: fixing subcorpus to covid for date 2022-04-20
# INFO ParlaMint-HR_T10_S11: replacing version 0.0a with 3.0a
# INFO ParlaMint-HR_T10_S11: preserving body tagUsage 1
# INFO ParlaMint-HR_T10_S11: removing desc tagUsage 0
# INFO ParlaMint-HR_T10_S11: preserving div tagUsage 1
# INFO ParlaMint-HR_T10_S11: removing gap tagUsage 0
# INFO ParlaMint-HR_T10_S11: removing head tagUsage 0
# INFO ParlaMint-HR_T10_S11: removing kinesic tagUsage 0
# INFO ParlaMint-HR_T10_S11: removing note tagUsage 0
# INFO ParlaMint-HR_T10_S11: preserving seg tagUsage 134246
# INFO ParlaMint-HR_T10_S11: preserving text tagUsage 1
# INFO ParlaMint-HR_T10_S11: preserving u tagUsage 1
# INFO ParlaMint-HR_T10_S11: removing vocal tagUsage 0
# WARN ParlaMint-HR_T10_S11: fixing subcorpus to covid for date 2022-04-20
# INFO: processing root
# INFO ParlaMint-HR: preserving body tagUsage 89
# INFO ParlaMint-HR: removing desc tagUsage 0
# INFO ParlaMint-HR: preserving div tagUsage 89
# INFO ParlaMint-HR: removing gap tagUsage 0
# INFO ParlaMint-HR: removing head tagUsage 0
# INFO ParlaMint-HR: removing kinesic tagUsage 0
# INFO ParlaMint-HR: removing note tagUsage 0
# INFO ParlaMint-HR: replacing seg tagUsage 4515429 with 4.515429E6
# INFO ParlaMint-HR: preserving text tagUsage 89
# INFO ParlaMint-HR: preserving u tagUsage 89
# INFO ParlaMint-HR: removing vocal tagUsage 0
# TODO: replace parla.legislature taxonomy with xi:include
# Source file Data/ParlaMint-HR/ParlaMint-HR.ana.xml does not exist
# cp: -r not specified; omitting directory 'add-common-content/ParlaMint-HR'

# %%
# %%bash
# cd /home/rupnik/parlamint/ParlaMint
# make validate-parlamint-HR
# Out:
# Scripts/validate-parlamint.pl Schema 'Data/ParlaMint-HR'
# INFO: Validating directory /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR
# INFO: Validating TEI root /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR.xml
# INFO: XML validation for ParlaMint-HR.xml
# INFO: Content validaton for ParlaMint-HR.xml
# INFO: particDesc content validaton for ParlaMint-HR.xml
# INFO[10] : Total number of affiliations with government.HR: 0
# ERROR[10] : government-role organisation without affiliation: #government.HR
# INFO[10] : Total number of affiliations with HS: 1141
# INFO[10] : Total number of affiliations with party.DC: 4
# INFO[10] : Total number of affiliations with party.HDSSB: 23
# INFO[10] : Total number of affiliations with party.HDZ: 458
# INFO[10] : Total number of affiliations with party.HNS: 56
# INFO[10] : Total number of affiliations with party.HSLS: 9
# INFO[10] : Total number of affiliations with party.HSP: 8
# INFO[10] : Total number of affiliations with party.HSS: 35
# INFO[10] : Total number of affiliations with party.HSU: 14
# INFO[10] : Total number of affiliations with party.IDS: 19
# INFO[10] : Total number of affiliations with party.LIBRA: 0
# WARN[10] : parliamentaryGroup-role organisation without affiliation: #party.LIBRA
# INFO[10] : Total number of affiliations with party.LS: 0
# WARN[10] : parliamentaryGroup-role organisation without affiliation: #party.LS
# INFO[10] : Total number of affiliations with party.MDS: 1
# INFO[10] : Total number of affiliations with party.PGS: 1
# INFO[10] : Total number of affiliations with party.SBHS: 1
# INFO[10] : Total number of affiliations with party.SDAH: 2
# INFO[10] : Total number of affiliations with party.SDP: 287
# INFO[10] : Total number of affiliations with party.SDSS: 22
# INFO[10] : Total number of affiliations with party.HRVATSKI_LABURISTI: 6
# INFO[10] : Total number of affiliations with party.HSD: 1
# INFO[10] : Total number of affiliations with party.BDSH: 1
# INFO[10] : Total number of affiliations with party.HGS: 2
# INFO[10] : Total number of affiliations with party.HSP_AS: 5
# INFO[10] : Total number of affiliations with party.ID: 1
# INFO[10] : Total number of affiliations with party.NAPRIJED_HRVATSKA: 1
# INFO[10] : Total number of affiliations with party.NOVI_VAL: 1
# INFO[10] : Total number of affiliations with party.ORAH: 3
# INFO[10] : Total number of affiliations with party.REFORMISTI: 7
# INFO[10] : Total number of affiliations with party.BM365: 1
# INFO[10] : Total number of affiliations with party.BUZ: 1
# INFO[10] : Total number of affiliations with party.HDS: 4
# INFO[10] : Total number of affiliations with party.HRAST: 2
# INFO[10] : Total number of affiliations with party.HRID: 2
# INFO[10] : Total number of affiliations with party.MOST: 37
# INFO[10] : Total number of affiliations with party.NLSP: 1
# INFO[10] : Total number of affiliations with party.PH: 5
# INFO[10] : Total number of affiliations with party.ŽIVI_ZID: 4
# INFO[10] : Total number of affiliations with party.GLAS: 5
# INFO[10] : Total number of affiliations with party.SMSH: 1
# INFO[10] : Total number of affiliations with party.SNAGA: 1
# INFO[10] : Total number of affiliations with party.DP: 11
# INFO[10] : Total number of affiliations with party.ZK: 5
# INFO[10] : Total number of affiliations with party.SIP: 1
# INFO[10] : Total number of affiliations with party.PAMETNO: 1
# INFO[10] : Total number of affiliations with party.FOKUS: 2
# INFO[10] : Total number of affiliations with party.NEZAVISNI: 87
# INFO[10] : Total number of affiliations with party.HS: 1
# INFO[10] : Total number of affiliations with party.HKS: 1
# INFO[12] : Total number of organizations with parliament role: 1
# INFO[12] : Total number of organizations with government role: 1
# INFO[12] : Total number of organizations with parliamentaryGroup role: 47
# INFO[??] : Total number of affiliations 2282
# INFO[??] : Total number of NO-role affiliations 0
# INFO[??] : Total number of 'member' role affiliations 2282
# INFO: Link checking for ParlaMint-HR.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S01.xml
# INFO: XML validation for ParlaMint-HR_T05_S01.xml
# INFO: Content validaton for ParlaMint-HR_T05_S01.xml
# WARN ParlaMint-HR_T05_S01: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S01.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S02.xml
# INFO: XML validation for ParlaMint-HR_T05_S02.xml
# INFO: Content validaton for ParlaMint-HR_T05_S02.xml
# WARN ParlaMint-HR_T05_S02: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S02.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S03.xml
# INFO: XML validation for ParlaMint-HR_T05_S03.xml
# INFO: Content validaton for ParlaMint-HR_T05_S03.xml
# WARN ParlaMint-HR_T05_S03: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S03.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S04.xml
# INFO: XML validation for ParlaMint-HR_T05_S04.xml
# INFO: Content validaton for ParlaMint-HR_T05_S04.xml
# WARN ParlaMint-HR_T05_S04: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S04.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S05.xml
# INFO: XML validation for ParlaMint-HR_T05_S05.xml
# INFO: Content validaton for ParlaMint-HR_T05_S05.xml
# WARN ParlaMint-HR_T05_S05: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S05.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S06.xml
# INFO: XML validation for ParlaMint-HR_T05_S06.xml
# INFO: Content validaton for ParlaMint-HR_T05_S06.xml
# WARN ParlaMint-HR_T05_S06: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S06.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S07.xml
# INFO: XML validation for ParlaMint-HR_T05_S07.xml
# INFO: Content validaton for ParlaMint-HR_T05_S07.xml
# WARN ParlaMint-HR_T05_S07: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S07.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S08.xml
# INFO: XML validation for ParlaMint-HR_T05_S08.xml
# INFO: Content validaton for ParlaMint-HR_T05_S08.xml
# WARN ParlaMint-HR_T05_S08: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S08.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S09.xml
# INFO: XML validation for ParlaMint-HR_T05_S09.xml
# INFO: Content validaton for ParlaMint-HR_T05_S09.xml
# WARN ParlaMint-HR_T05_S09: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S09.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S10.xml
# INFO: XML validation for ParlaMint-HR_T05_S10.xml
# INFO: Content validaton for ParlaMint-HR_T05_S10.xml
# WARN ParlaMint-HR_T05_S10: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S10.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S11.xml
# INFO: XML validation for ParlaMint-HR_T05_S11.xml
# INFO: Content validaton for ParlaMint-HR_T05_S11.xml
# WARN ParlaMint-HR_T05_S11: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S11.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S12.xml
# INFO: XML validation for ParlaMint-HR_T05_S12.xml
# INFO: Content validaton for ParlaMint-HR_T05_S12.xml
# WARN ParlaMint-HR_T05_S12: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S12.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S13.xml
# INFO: XML validation for ParlaMint-HR_T05_S13.xml
# INFO: Content validaton for ParlaMint-HR_T05_S13.xml
# WARN ParlaMint-HR_T05_S13: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S13.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S14.xml
# INFO: XML validation for ParlaMint-HR_T05_S14.xml
# INFO: Content validaton for ParlaMint-HR_T05_S14.xml
# WARN ParlaMint-HR_T05_S14: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S14.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S15.xml
# INFO: XML validation for ParlaMint-HR_T05_S15.xml
# INFO: Content validaton for ParlaMint-HR_T05_S15.xml
# WARN ParlaMint-HR_T05_S15: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S15.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S16.xml
# INFO: XML validation for ParlaMint-HR_T05_S16.xml
# INFO: Content validaton for ParlaMint-HR_T05_S16.xml
# WARN ParlaMint-HR_T05_S16: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S16.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S17.xml
# INFO: XML validation for ParlaMint-HR_T05_S17.xml
# INFO: Content validaton for ParlaMint-HR_T05_S17.xml
# WARN ParlaMint-HR_T05_S17: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S17.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S18.xml
# INFO: XML validation for ParlaMint-HR_T05_S18.xml
# INFO: Content validaton for ParlaMint-HR_T05_S18.xml
# WARN ParlaMint-HR_T05_S18: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S18.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S19.xml
# INFO: XML validation for ParlaMint-HR_T05_S19.xml
# INFO: Content validaton for ParlaMint-HR_T05_S19.xml
# WARN ParlaMint-HR_T05_S19: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S19.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S20.xml
# INFO: XML validation for ParlaMint-HR_T05_S20.xml
# INFO: Content validaton for ParlaMint-HR_T05_S20.xml
# WARN ParlaMint-HR_T05_S20: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S20.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S21.xml
# INFO: XML validation for ParlaMint-HR_T05_S21.xml
# INFO: Content validaton for ParlaMint-HR_T05_S21.xml
# WARN ParlaMint-HR_T05_S21: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S21.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S22.xml
# INFO: XML validation for ParlaMint-HR_T05_S22.xml
# INFO: Content validaton for ParlaMint-HR_T05_S22.xml
# WARN ParlaMint-HR_T05_S22: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S22.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S23.xml
# INFO: XML validation for ParlaMint-HR_T05_S23.xml
# INFO: Content validaton for ParlaMint-HR_T05_S23.xml
# WARN ParlaMint-HR_T05_S23: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S23.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S24.xml
# INFO: XML validation for ParlaMint-HR_T05_S24.xml
# INFO: Content validaton for ParlaMint-HR_T05_S24.xml
# WARN ParlaMint-HR_T05_S24: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S24.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S25.xml
# INFO: XML validation for ParlaMint-HR_T05_S25.xml
# INFO: Content validaton for ParlaMint-HR_T05_S25.xml
# WARN ParlaMint-HR_T05_S25: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S25.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S26.xml
# INFO: XML validation for ParlaMint-HR_T05_S26.xml
# INFO: Content validaton for ParlaMint-HR_T05_S26.xml
# WARN ParlaMint-HR_T05_S26: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S26.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T05_S27.xml
# INFO: XML validation for ParlaMint-HR_T05_S27.xml
# INFO: Content validaton for ParlaMint-HR_T05_S27.xml
# WARN ParlaMint-HR_T05_S27: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T05_S27.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S01.xml
# INFO: XML validation for ParlaMint-HR_T06_S01.xml
# INFO: Content validaton for ParlaMint-HR_T06_S01.xml
# WARN ParlaMint-HR_T06_S01: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S01.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S02.xml
# INFO: XML validation for ParlaMint-HR_T06_S02.xml
# INFO: Content validaton for ParlaMint-HR_T06_S02.xml
# WARN ParlaMint-HR_T06_S02: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S02.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S03.xml
# INFO: XML validation for ParlaMint-HR_T06_S03.xml
# INFO: Content validaton for ParlaMint-HR_T06_S03.xml
# WARN ParlaMint-HR_T06_S03: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S03.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S04.xml
# INFO: XML validation for ParlaMint-HR_T06_S04.xml
# INFO: Content validaton for ParlaMint-HR_T06_S04.xml
# WARN ParlaMint-HR_T06_S04: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S04.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S05.xml
# INFO: XML validation for ParlaMint-HR_T06_S05.xml
# INFO: Content validaton for ParlaMint-HR_T06_S05.xml
# WARN ParlaMint-HR_T06_S05: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S05.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S06.xml
# INFO: XML validation for ParlaMint-HR_T06_S06.xml
# INFO: Content validaton for ParlaMint-HR_T06_S06.xml
# WARN ParlaMint-HR_T06_S06: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S06.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S07.xml
# INFO: XML validation for ParlaMint-HR_T06_S07.xml
# INFO: Content validaton for ParlaMint-HR_T06_S07.xml
# WARN ParlaMint-HR_T06_S07: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S07.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S08.xml
# INFO: XML validation for ParlaMint-HR_T06_S08.xml
# INFO: Content validaton for ParlaMint-HR_T06_S08.xml
# WARN ParlaMint-HR_T06_S08: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S08.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S09.xml
# INFO: XML validation for ParlaMint-HR_T06_S09.xml
# INFO: Content validaton for ParlaMint-HR_T06_S09.xml
# WARN ParlaMint-HR_T06_S09: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S09.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S10.xml
# INFO: XML validation for ParlaMint-HR_T06_S10.xml
# INFO: Content validaton for ParlaMint-HR_T06_S10.xml
# WARN ParlaMint-HR_T06_S10: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S10.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S11.xml
# INFO: XML validation for ParlaMint-HR_T06_S11.xml
# INFO: Content validaton for ParlaMint-HR_T06_S11.xml
# WARN ParlaMint-HR_T06_S11: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S11.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S12.xml
# INFO: XML validation for ParlaMint-HR_T06_S12.xml
# INFO: Content validaton for ParlaMint-HR_T06_S12.xml
# WARN ParlaMint-HR_T06_S12: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S12.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S13.xml
# INFO: XML validation for ParlaMint-HR_T06_S13.xml
# INFO: Content validaton for ParlaMint-HR_T06_S13.xml
# WARN ParlaMint-HR_T06_S13: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S13.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S14.xml
# INFO: XML validation for ParlaMint-HR_T06_S14.xml
# INFO: Content validaton for ParlaMint-HR_T06_S14.xml
# WARN ParlaMint-HR_T06_S14: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S14.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S15.xml
# INFO: XML validation for ParlaMint-HR_T06_S15.xml
# INFO: Content validaton for ParlaMint-HR_T06_S15.xml
# WARN ParlaMint-HR_T06_S15: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S15.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S16.xml
# INFO: XML validation for ParlaMint-HR_T06_S16.xml
# INFO: Content validaton for ParlaMint-HR_T06_S16.xml
# WARN ParlaMint-HR_T06_S16: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S16.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S17.xml
# INFO: XML validation for ParlaMint-HR_T06_S17.xml
# INFO: Content validaton for ParlaMint-HR_T06_S17.xml
# WARN ParlaMint-HR_T06_S17: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S17.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S18.xml
# INFO: XML validation for ParlaMint-HR_T06_S18.xml
# INFO: Content validaton for ParlaMint-HR_T06_S18.xml
# WARN ParlaMint-HR_T06_S18: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S18.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S19.xml
# INFO: XML validation for ParlaMint-HR_T06_S19.xml
# INFO: Content validaton for ParlaMint-HR_T06_S19.xml
# WARN ParlaMint-HR_T06_S19: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S19.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S20.xml
# INFO: XML validation for ParlaMint-HR_T06_S20.xml
# INFO: Content validaton for ParlaMint-HR_T06_S20.xml
# WARN ParlaMint-HR_T06_S20: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S20.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S21.xml
# INFO: XML validation for ParlaMint-HR_T06_S21.xml
# INFO: Content validaton for ParlaMint-HR_T06_S21.xml
# WARN ParlaMint-HR_T06_S21: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S21.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S22.xml
# INFO: XML validation for ParlaMint-HR_T06_S22.xml
# INFO: Content validaton for ParlaMint-HR_T06_S22.xml
# WARN ParlaMint-HR_T06_S22: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S22.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S23.xml
# INFO: XML validation for ParlaMint-HR_T06_S23.xml
# INFO: Content validaton for ParlaMint-HR_T06_S23.xml
# WARN ParlaMint-HR_T06_S23: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S23.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T06_S24.xml
# INFO: XML validation for ParlaMint-HR_T06_S24.xml
# INFO: Content validaton for ParlaMint-HR_T06_S24.xml
# WARN ParlaMint-HR_T06_S24: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T06_S24.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S01.xml
# INFO: XML validation for ParlaMint-HR_T07_S01.xml
# INFO: Content validaton for ParlaMint-HR_T07_S01.xml
# WARN ParlaMint-HR_T07_S01: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S01.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S02.xml
# INFO: XML validation for ParlaMint-HR_T07_S02.xml
# INFO: Content validaton for ParlaMint-HR_T07_S02.xml
# WARN ParlaMint-HR_T07_S02: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S02.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S03.xml
# INFO: XML validation for ParlaMint-HR_T07_S03.xml
# INFO: Content validaton for ParlaMint-HR_T07_S03.xml
# WARN ParlaMint-HR_T07_S03: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S03.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S04.xml
# INFO: XML validation for ParlaMint-HR_T07_S04.xml
# INFO: Content validaton for ParlaMint-HR_T07_S04.xml
# WARN ParlaMint-HR_T07_S04: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S04.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S05.xml
# INFO: XML validation for ParlaMint-HR_T07_S05.xml
# INFO: Content validaton for ParlaMint-HR_T07_S05.xml
# WARN ParlaMint-HR_T07_S05: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S05.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S06.xml
# INFO: XML validation for ParlaMint-HR_T07_S06.xml
# INFO: Content validaton for ParlaMint-HR_T07_S06.xml
# WARN ParlaMint-HR_T07_S06: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S06.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S07.xml
# INFO: XML validation for ParlaMint-HR_T07_S07.xml
# INFO: Content validaton for ParlaMint-HR_T07_S07.xml
# WARN ParlaMint-HR_T07_S07: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S07.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S08.xml
# INFO: XML validation for ParlaMint-HR_T07_S08.xml
# INFO: Content validaton for ParlaMint-HR_T07_S08.xml
# WARN ParlaMint-HR_T07_S08: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S08.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S09.xml
# INFO: XML validation for ParlaMint-HR_T07_S09.xml
# INFO: Content validaton for ParlaMint-HR_T07_S09.xml
# WARN ParlaMint-HR_T07_S09: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S09.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S10.xml
# INFO: XML validation for ParlaMint-HR_T07_S10.xml
# INFO: Content validaton for ParlaMint-HR_T07_S10.xml
# WARN ParlaMint-HR_T07_S10: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S10.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S11.xml
# INFO: XML validation for ParlaMint-HR_T07_S11.xml
# INFO: Content validaton for ParlaMint-HR_T07_S11.xml
# WARN ParlaMint-HR_T07_S11: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S11.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S12.xml
# INFO: XML validation for ParlaMint-HR_T07_S12.xml
# INFO: Content validaton for ParlaMint-HR_T07_S12.xml
# WARN ParlaMint-HR_T07_S12: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S12.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S13.xml
# INFO: XML validation for ParlaMint-HR_T07_S13.xml
# INFO: Content validaton for ParlaMint-HR_T07_S13.xml
# WARN ParlaMint-HR_T07_S13: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S13.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S14.xml
# INFO: XML validation for ParlaMint-HR_T07_S14.xml
# INFO: Content validaton for ParlaMint-HR_T07_S14.xml
# WARN ParlaMint-HR_T07_S14: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S14.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S15.xml
# INFO: XML validation for ParlaMint-HR_T07_S15.xml
# INFO: Content validaton for ParlaMint-HR_T07_S15.xml
# WARN ParlaMint-HR_T07_S15: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S15.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S16.xml
# INFO: XML validation for ParlaMint-HR_T07_S16.xml
# INFO: Content validaton for ParlaMint-HR_T07_S16.xml
# WARN ParlaMint-HR_T07_S16: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S16.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S17.xml
# INFO: XML validation for ParlaMint-HR_T07_S17.xml
# INFO: Content validaton for ParlaMint-HR_T07_S17.xml
# WARN ParlaMint-HR_T07_S17: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S17.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S18.xml
# INFO: XML validation for ParlaMint-HR_T07_S18.xml
# INFO: Content validaton for ParlaMint-HR_T07_S18.xml
# WARN ParlaMint-HR_T07_S18: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S18.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S19.xml
# INFO: XML validation for ParlaMint-HR_T07_S19.xml
# INFO: Content validaton for ParlaMint-HR_T07_S19.xml
# WARN ParlaMint-HR_T07_S19: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S19.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T07_S20.xml
# INFO: XML validation for ParlaMint-HR_T07_S20.xml
# INFO: Content validaton for ParlaMint-HR_T07_S20.xml
# WARN ParlaMint-HR_T07_S20: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T07_S20.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T08_S01.xml
# INFO: XML validation for ParlaMint-HR_T08_S01.xml
# INFO: Content validaton for ParlaMint-HR_T08_S01.xml
# WARN ParlaMint-HR_T08_S01: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T08_S01.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T08_S02.xml
# INFO: XML validation for ParlaMint-HR_T08_S02.xml
# INFO: Content validaton for ParlaMint-HR_T08_S02.xml
# WARN ParlaMint-HR_T08_S02: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T08_S02.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T08_S03.xml
# INFO: XML validation for ParlaMint-HR_T08_S03.xml
# INFO: Content validaton for ParlaMint-HR_T08_S03.xml
# WARN ParlaMint-HR_T08_S03: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T08_S03.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T09_S01.xml
# INFO: XML validation for ParlaMint-HR_T09_S01.xml
# INFO: Content validaton for ParlaMint-HR_T09_S01.xml
# WARN ParlaMint-HR_T09_S01: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T09_S01.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T09_S02.xml
# INFO: XML validation for ParlaMint-HR_T09_S02.xml
# INFO: Content validaton for ParlaMint-HR_T09_S02.xml
# WARN ParlaMint-HR_T09_S02: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T09_S02.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T09_S03.xml
# INFO: XML validation for ParlaMint-HR_T09_S03.xml
# INFO: Content validaton for ParlaMint-HR_T09_S03.xml
# WARN ParlaMint-HR_T09_S03: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T09_S03.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T09_S04.xml
# INFO: XML validation for ParlaMint-HR_T09_S04.xml
# INFO: Content validaton for ParlaMint-HR_T09_S04.xml
# WARN ParlaMint-HR_T09_S04: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T09_S04.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S01.xml
# INFO: XML validation for ParlaMint-HR_T10_S01.xml
# INFO: Content validaton for ParlaMint-HR_T10_S01.xml
# WARN ParlaMint-HR_T10_S01: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S01.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S02.xml
# INFO: XML validation for ParlaMint-HR_T10_S02.xml
# INFO: Content validaton for ParlaMint-HR_T10_S02.xml
# WARN ParlaMint-HR_T10_S02: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S02.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S03.xml
# INFO: XML validation for ParlaMint-HR_T10_S03.xml
# INFO: Content validaton for ParlaMint-HR_T10_S03.xml
# WARN ParlaMint-HR_T10_S03: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S03.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S04.xml
# INFO: XML validation for ParlaMint-HR_T10_S04.xml
# INFO: Content validaton for ParlaMint-HR_T10_S04.xml
# WARN ParlaMint-HR_T10_S04: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S04.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S05.xml
# INFO: XML validation for ParlaMint-HR_T10_S05.xml
# INFO: Content validaton for ParlaMint-HR_T10_S05.xml
# WARN ParlaMint-HR_T10_S05: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S05.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S06.xml
# INFO: XML validation for ParlaMint-HR_T10_S06.xml
# INFO: Content validaton for ParlaMint-HR_T10_S06.xml
# WARN ParlaMint-HR_T10_S06: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S06.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S07.xml
# INFO: XML validation for ParlaMint-HR_T10_S07.xml
# INFO: Content validaton for ParlaMint-HR_T10_S07.xml
# WARN ParlaMint-HR_T10_S07: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S07.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S08.xml
# INFO: XML validation for ParlaMint-HR_T10_S08.xml
# INFO: Content validaton for ParlaMint-HR_T10_S08.xml
# WARN ParlaMint-HR_T10_S08: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S08.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S09.xml
# INFO: XML validation for ParlaMint-HR_T10_S09.xml
# INFO: Content validaton for ParlaMint-HR_T10_S09.xml
# WARN ParlaMint-HR_T10_S09: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S09.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S10.xml
# INFO: XML validation for ParlaMint-HR_T10_S10.xml
# INFO: Content validaton for ParlaMint-HR_T10_S10.xml
# WARN ParlaMint-HR_T10_S10: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S10.xml
# INFO: Validating component TEI file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-HR/ParlaMint-HR_T10_S11.xml
# INFO: XML validation for ParlaMint-HR_T10_S11.xml
# INFO: Content validaton for ParlaMint-HR_T10_S11.xml
# WARN ParlaMint-HR_T10_S11: TEI ID should have only one underscore
# INFO: Link checking for ParlaMint-HR_T10_S11.xml

# %% [markdown]
# # Notes on the output:
# <!--
# `ParlaMint-HR.xml:473:55: error: value of attribute "to" is invalid; must be an ISO year and month, must be an ISO date, must be an ISO date and time or must be a year`: this is because I set the end of term 10 as ongoing instead of a date.
#
# `ParlaMint-HR.xml:595:66: error: value of attribute "xml:id" is invalid; must be an XML name without colons`: ~~Will try to fix by removing punctuations from party references. There aren't any colons in the name, though.~~ Yup, this worked.
#
# `ParlaMint-HR.xml:727:26: error: value of attribute "name" is invalid; must be equal to "coalition", "opposition", "renaming", "representing" or "successor"`: value was "oposition" [sic.] This is since corrected. -->
#
# <!-- ```
# ParlaMint-HR.xml:7829:45: error: ID "LovrićMerzelMarina" has already been defined
# ParlaMint-HR.xml:6797:45: error: first occurrence of ID "LovrićMerzelMarina"
# ParlaMint-HR.xml:8645:42: error: ID "VrbatGrgićTanja" has already been defined
# ParlaMint-HR.xml:6506:42: error: first occurrence of ID "VrbatGrgićTanja"
# ```
# this stems from the fact that those two MP have twin `codeMPs`.  -->
#
# <!-- Errors I should focus on:
# `ERROR ParlaMint-HR_T06: ERROR: Can't find local id for u/@who="#ErrorError:row['Speaker_name']='Nepoznat',row['lastname']=nan,row['firstname']=nan"`: Clearly missing data.
#
# Other errors that I do not know how to remedy:
#
# ```
# ERROR ParlaMint-HR: Duplicate party affiliation for #HS
# ERROR ParlaMint-HR: Duplicate party affiliation for #party.SDP
# ```
#
# ERROR ParlaMint-HR_T05: ERROR: Can't find local id for u/@who="#PalarićAntun"
#  -->

# %% [markdown]
# # Adding missing persons:
# ~~Only {'MatulovićDropulićMarina'} will have to be added artificially.~~ Added {'MatulovićDropulićMarina'}.

# %%
f = "008_validation_out"
with open(f) as f:
    content = f.readlines()
# Pattern to catch:
# ERROR: Can't find local id for u/@who="#MatulovićDropulićMarina"

pattern = '''{begining}find local id for u/@who="#{name}"\n'''
from parse import compile
p = compile(pattern)

missing = set()
for line in content:
    result = p.parse(line)
    try:
        missing.add(result["name"])
    except:
        continue
missing
# Out:
# set()
