# %%
from pathlib import Path
from tempfile import NamedTemporaryFile
from utils import prepare_interim_files, construct_TEI
from parse import compile
from concurrent.futures import ProcessPoolExecutor

datadir = Path("/home/rupnik/parlamint/S_data/")

# Identify all (T,S) pairs:
files = list(datadir.glob("*"))
pattern = "{prefix}_T{term:02}_S{session:02}.{ending}"
p = compile(pattern)
terms_and_sessions = set((p.parse(i.name).named["term"], p.parse(i.name).named["session"]) for i in files)


def process(term, session) -> None:
    term, session = int(term), int(session)
    text_path = datadir / (f"text_T{term:02}_S{session:02}.txt")
    meta_path = datadir / (f"meta_T{term:02}_S{session:02}.tsv")
    mp_path = Path("/home/rupnik/parlamint/") / Path("Croatia_MPs_final_ 20220917.xlsx")
    parties_path = Path("/home/rupnik/parlamint/") / Path("Croatia_parties_final_20220917.xlsx")
    
    merged_file = NamedTemporaryFile()
    prepare_interim_files(
        text_path = text_path,
        meta_path = meta_path,
        mp_path = mp_path,
        parties_path= parties_path,
        out_file = merged_file.name
    )
    
    construct_TEI(
        pickled_file = merged_file.name,
        session_index=session,
        term_index=term,
        out_file = Path("/home/rupnik/parlamint/S/") / f"ParlaMint-HR_T{term:02}_S{session:02}.xml"
        )
    
    
# with ProcessPoolExecutor(max_workers=20) as executor:
#     futures = executor.map(process, [term for term, session in terms_and_sessions], [session for term, session in terms_and_sessions])

for term, session in list(terms_and_sessions):
    process(term, session)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: Exception ignored in: <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>Exception ignored in: <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10><function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10><function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10><function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
#
# <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10><function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
#
# Traceback (most recent call last):
#
# Traceback (most recent call last):
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#       File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# Traceback (most recent call last):
# Traceback (most recent call last):
# Exception ignored in:   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#       File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# self.close()<function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>    self.close()Exception ignored in:
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#
# self.close()<function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>self.close()  File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#
#     Traceback (most recent call last):
#
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
# unlink(self.name)  File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# self.close()Traceback (most recent call last):
#
#   0%|          | 0/1 [00:00<?, ?it/s]self.close()self.close()  File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#       File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
# FileNotFoundError
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#     : unlink(self.name)    self.close()self.close()[Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#       File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#
#
#
# FileNotFoundError  File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
# unlink(self.name)      File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
# :
#         unlink(self.name)unlink(self.name)unlink(self.name)unlink(self.name)Exception ignored in: FileNotFoundError
#
#
# <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>: FileNotFoundErrorFileNotFoundError    Exception ignored in:
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc': unlink(self.name)unlink(self.name)[Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'[Errno 2] No such file or directory: '/tmp/tmpc_kqmumc': <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>[Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
# [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
#
#
#
# FileNotFoundErrorTraceback (most recent call last):
#
#
#
# FileNotFoundErrorTraceback (most recent call last):
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# :   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# FileNotFoundError
# [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
# self.close(): self.close()[Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
#
# : [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'Exception ignored in:   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
# Exception ignored in:
# <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#     Traceback (most recent call last):
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#         self.close()unlink(self.name)
# <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>  File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#     unlink(self.name)
# FileNotFoundError: Exception ignored in:
# unlink(self.name)
# <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>FileNotFoundErrorTraceback (most recent call last):
#
# :
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'FileNotFoundError
#     [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'self.close()
# Traceback (most recent call last):
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
# Exception ignored in: :   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
# <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
# [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'Traceback (most recent call last):
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#         self.close()
# unlink(self.name)
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
# FileNotFoundError:     [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'unlink(self.name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'self.close()
#
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#   0%|          | 0/1 [00:00<?, ?it/s]    unlink(self.name)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
# Exception ignored in: <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
# Traceback (most recent call last):
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#     self.close()
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#     unlink(self.name)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
# 2022-10-27 11:34:38 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022-10-27 11:34:38 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022
):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022-10-27 11:34:38 INFO: Use device: cpu
# 2022-10-27 11:34:38 INFO: Loading: tokenize
# 2022-10-27 11:34:38 INFO: Done loading processors!
# 2022-10-27 11:34:38 INFO: Done loading processors!
# 2022-10-27 11:34:38 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022-10-27 11:34:38 INFO: Use device: cpu
# 2022-10-27 11:34:38 INFO: Loading: tokenize
# 2022-10-27 11:34:38 INFO: Done loading processors!
# Exception ignored in: <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
# Traceback (most recent call last):
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#     self.close()
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#     unlink(self.name)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
# 2022-10-27 11:34:38 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022-10-27 11:34:38 INFO: Use device: cpu
# 2022-10-27 11:34:38 INFO: Loading: tokenize
# 2022-10-27 11:34:38 INFO: Done loading processors!
# Exception ignored in: <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
# Traceback (most recent call last):
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#     self.close()
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#     unlink(self.name)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
# Exception ignored in: <function _TemporaryFileCloser.__del__ at 0x7fd4d6eafc10>
# Traceback (most recent call last):
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 441, in __del__
#     self.close()
#   File "/home/rupnik/anaconda3/lib/python3.9/tempfile.py", line 437, in close
#     unlink(self.name)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpc_kqmumc'
# 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# 2022-10-27 11:34:39 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022-10-27 11:34:39 INFO: Use device: cpu
# 2022-10-27 11:34:39 INFO: Loading: tokenize
# 2022-10-27 11:34:39 INFO: Done loading processors!
# 2022-10-27 11:34:39 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022-10-27 11:34:39 INFO: Use device: cpu
# 2022-10-27 11:34:39 INFO: Loading: tokenize
# 2022-10-27 11:34:39 INFO: Done loading processors!
# 2022-10-27 11:34:39 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# ========================
#
# 2022-10-27 11:34:39 INFO: Use device: cpu
# 2022-10-27 11:34:39 INFO: Loading: tokenize
# 2022-10-27 11:34:39 INFO: Done loading processors!
# 100%|██████████| 1/1 [00:05<00:00,  5.62s/it]
# 100%|██████████| 1/1 [00:05<00:00,  5.69s/it]
# 100%|██████████| 1/1 [00:07<00:00,  7.43s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.10s/it]
# 100%|██████████| 1/1 [00:00<00:00, 26.18it/s]
# 100%|██████████| 1/1 [00:09<00:00,  9.13s/it]
# 100%|██████████| 1/1 [00:16<00:00, 16.76s/it]
# 100%|██████████| 1/1 [00:16<00:00, 16.78s/it]
# 100%|██████████| 1/1 [00:17<00:00, 17.94s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6269/4180979577.py in <module>
#      39
#      40 with ProcessPoolExecutor(max_workers=20) as executor:
# ---> 41     futures = executor.map(process, [term for term, session in terms_and_sessions], [session for term, session in terms_and_sessions])
#      42
#      43 # for term, session in list(terms_and_sessions):
#
# ~/anaconda3/lib/python3.9/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     634
#     635     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 636         self.shutdown(wait=True)
#     637         return False
#     638
#
# ~/anaconda3/lib/python3.9/concurrent/futures/process.py in shutdown(self, wait, cancel_futures)
#     738
#     739         if self._executor_manager_thread is not None and wait:
# --> 740             self._executor_manager_thread.join()
#     741         # To reduce the risk of opening too many files, remove references to
#     742         # objects that use file descriptors.
#
# ~/anaconda3/lib/python3.9/threading.py in join(self, timeout)
#    1051
#    1052         if timeout is None:
# -> 1053             self._wait_for_tstate_lock()
#    1054         else:
#    1055             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1067         if lock is None:  # already determined that the C code is done
#    1068             assert self._is_stopped
# -> 1069         elif lock.acquire(block, timeout):
#    1070             lock.release()
#    1071             self._stop()
#
# KeyboardInterrupt:
# 100%|██████████| 1/1 [00:22<00:00, 22.02s/it]
# 100%|██████████| 1/1 [00:27<00:00, 27.31s/it]
# 100%|██████████| 1/1 [00:32<00:00, 32.07s/it]
# 100%|██████████| 1/1 [00:32<00:00, 32.82s/it]
# 100%|██████████| 1/1 [00:35<00:00, 35.33s/it]
# 100%|██████████| 1/1 [00:05<00:00,  5.38s/it]
# 100%|██████████| 1/1 [00:38<00:00, 38.74s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.34it/s]
# 100%|██████████| 1/1 [00:40<00:00, 40.11s/it]
# 100%|██████████| 1/1 [00:35<00:00, 35.65s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.86it/s]
# 100%|██████████| 1/1 [00:37<00:00, 37.71s/it]
# 100%|██████████| 1/1 [00:08<00:00,  8.51s/it]
# 100%|██████████| 1/1 [00:46<00:00, 46.83s/it]
# 100%|██████████| 1/1 [00:56<00:00, 56.09s/it]
# 100%|██████████| 1/1 [00:55<00:00, 55.92s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# 100%|██████████| 1/1 [01:07<00:00, 67.18s/it]
# 100%|██████████| 1/1 [01:16<00:00, 76.30s/it]
# 100%|██████████| 1/1 [00:44<00:00, 44.09s/it]
# 100%|██████████| 1/1 [01:00<00:00, 60.85s/it]
# 100%|██████████| 1/1 [00:43<00:00, 43.73s/it]
# 100%|██████████| 1/1 [01:27<00:00, 87.23s/it]
# 100%|██████████| 1/1 [01:27<00:00, 87.95s/it]
# 100%|██████████| 1/1 [01:13<00:00, 73.73s/it]
# 100%|██████████| 1/1 [01:27<00:00, 87.65s/it]
# 100%|██████████| 1/1 [00:55<00:00, 55.94s/it]
# 100%|██████████| 1/1 [00:23<00:00, 23.69s/it]
# 100%|██████████| 1/1 [01:07<00:00, 67.99s/it]
# 100%|██████████| 1/1 [01:19<00:00, 79.57s/it]
# 100%|██████████| 1/1 [01:25<00:00, 85.72s/it]
# 100%|██████████| 1/1 [00:56<00:00, 56.97s/it]
# 100%|██████████| 1/1 [00:59<00:00, 59.08s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# 100%|██████████| 1/1 [00:23<00:00, 23.87s/it]
# 100%|██████████| 1/1 [01:07<00:00, 67.72s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
